# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ### Zonas Verdes

# %%
zonasVerdes = gpd.read_file("../../../Data/inventario_zonas_verdes.geojson")

# %%
zonasVerdes.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Corredores Verdes

# %%
corredores = gpd.read_file("../../../Data/pot48_2014_corredores_ver.geojson")

# %%
corredores.plot(column = "actuacion",legend = True)
plt.show()

# %% [markdown]
# ### Rio

# %%
rio = gpd.read_file("../../../Data/rio_medellin.geojson")

# %% [markdown]
# ### Aprovechamiento residuos

# %%
residuos = gpd.read_file("../../../Data/sitios_de_aprovechamiento.geojson")

# %%
residuos.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Rios Quebradas

# %%
riosQuebradas = gpd.read_file("../../../Data/Retiros_rios_quebradas.geojson")

# %%
riosQuebradas.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Riesgos

# %%
riesgos = gpd.read_file("../../../Data/pot48_2014_riesgos_avenid.geojson")

# %%
riesgos.plot(column = "riesgo",legend = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Amenazas Rio

# %%
inundacion = gpd.read_file("../../../Data/pot48_2014_amenaza_inunda.geojson")

# %%
inundacion.plot(column = "grado_amenaza",legend = True)
# Out:
# <Axes: >

# %% [markdown]
# ### espacio publico

# %%
publico = gpd.read_file("../../../Data/pot48_2014_espacio_public.geojson")

# %%
publico.categoria
# Out:
# array(['Area libre del equipamiento público',
#        'Area libre privada de uso público', 'Bienes de uso público'],
#       dtype=object)

# %%
publico.plot(column = "categoria",legend = True)
# Out:
# <Axes: >

# %% [markdown]
# ### red conectividad ecologica

# %%
conectividadEcologica = gpd.read_file("../../../Data/pot48_2014_red_conectivid.geojson")

# %%
conectividadEcologica.elemento.unique()
# Out:
# array(['Nodos y enlaces estructurantes proyectados',
#        'Enlace Estructurante', 'Nodo Estructurante',
#        'Áreas de Interés Recreativo y Paisajístico'], dtype=object)

# %%
conectividadEcologica.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### zonas receptoras derechos de construccion

# %%
derechosConstruccion = gpd.read_file("../../../Data/pot48_2014_zonas_receptor.geojson")

# %%
derechosConstruccion.plot(column = "tipo",legend = True)
# Out:
# <Axes: >

# %%
derechosConstruccion.tratamiento.unique()
# Out:
# array(['Consolidacion Nivel 1', 'Consolidacion Nivel 2',
#        'Renovación Urbana', 'Consolidacion Nivel 4'], dtype=object)

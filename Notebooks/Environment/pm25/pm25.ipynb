# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ### PM 25

# %% [markdown]
# #### Aranjuez

# %%
AranjuezPM25 = pd.read_csv("../../../Data/aranjuez,-medellín-air-quality.csv")

# %%
AranjuezPM25["date"] = pd.to_datetime(AranjuezPM25["date"])
AranjuezPM25.sort_values(by="date", inplace=True)
AranjuezPM25Monthly = AranjuezPM25.resample("ME", on="date").mean().reset_index()
AranjuezPM25Yearly = AranjuezPM25.resample("YE", on="date").mean().reset_index()

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(AranjuezPM25['date'], AranjuezPM25[' pm25'])
ax[0].set_title('Daily PM25')
ax[1].plot(AranjuezPM25Monthly['date'], AranjuezPM25Monthly[' pm25'])
ax[1].set_title('Monthly PM25')
ax[2].plot(AranjuezPM25Yearly['date'], AranjuezPM25Yearly[' pm25'])
ax[2].set_title('Yearly PM25')
plt.tight_layout()

# %% [markdown]
# #### Poblado

# %%
PobladoPM25 = pd.read_csv("../../../Data/el-poblado, medellín, colombia-air-quality.csv")

# %%
PobladoPM25["date"] = pd.to_datetime(PobladoPM25["date"])
PobladoPM25.sort_values(by="date", inplace=True)
PobladoPM25Monthly = PobladoPM25.resample("ME", on="date").mean().reset_index()
PobladoPM25Yearly = PobladoPM25.resample("YE", on="date").mean().reset_index()

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(PobladoPM25['date'], PobladoPM25[' pm25'])
ax[0].set_title('Daily PM25')
ax[1].plot(PobladoPM25Monthly['date'], PobladoPM25Monthly[' pm25'])
ax[1].set_title('Monthly PM25')
ax[2].plot(PobladoPM25Yearly['date'], PobladoPM25Yearly[' pm25'])
ax[2].set_title('Yearly PM25')
plt.tight_layout()

# %% [markdown]
# #### San Cristobal

# %%
sanCristobalPM25 = pd.read_csv("../../../Data/san-cristobal, medellín, colombia-air-quality.csv")

# %%
sanCristobalPM25["date"] = pd.to_datetime(sanCristobalPM25["date"])
sanCristobalPM25.sort_values(by="date", inplace=True)
sanCristobalPM25Monthly = sanCristobalPM25.resample("ME", on="date").mean().reset_index()
sanCristobalPM25Yearly = sanCristobalPM25.resample("YE", on="date").mean().reset_index()

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(sanCristobalPM25['date'], sanCristobalPM25[' pm25'])
ax[0].set_title('Daily PM25')
ax[1].plot(sanCristobalPM25Monthly['date'], sanCristobalPM25Monthly[' pm25'])
ax[1].set_title('Monthly PM25')
ax[2].plot(sanCristobalPM25Yearly['date'], sanCristobalPM25Yearly[' pm25'])
ax[2].set_title('Yearly PM25')
plt.tight_layout()

# %% [markdown]
# #### Villa Hermosa

# %%
villaHermosaPM25 = pd.read_csv("../../../Data/villahermosa,-medellín-air-quality.csv")

# %%
villaHermosaPM25["date"] = pd.to_datetime(villaHermosaPM25["date"])
villaHermosaPM25.sort_values(by="date", inplace=True)
villaHermosaPM25Monthly = villaHermosaPM25.resample("ME", on="date").mean().reset_index()
villaHermosaPM25Yearly = villaHermosaPM25.resample("YE", on="date").mean().reset_index()

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(villaHermosaPM25['date'], villaHermosaPM25[' pm25'])
ax[0].set_title('Daily PM25')
ax[1].plot(villaHermosaPM25Monthly['date'], villaHermosaPM25Monthly[' pm25'])
ax[1].set_title('Monthly PM25')
ax[2].plot(villaHermosaPM25Yearly['date'], villaHermosaPM25Yearly[' pm25'])
ax[2].set_title('Yearly PM25')
plt.tight_layout()

# %% [markdown]
# #### La candelaria

# %%
laCandelariaPM25 = pd.read_csv("../../../Data/museo-de antioquia, medellín-air-quality.csv")[["date"," pm25"]]

# %%
laCandelariaPM25["date"] = pd.to_datetime(laCandelariaPM25["date"])
laCandelariaPM25.sort_values(by="date", inplace=True)
laCandelariaPM25[" pm25"] = laCandelariaPM25[" pm25"].replace(" ",np.nan)
laCandelariaPM25.dropna(inplace=True)

# %%
laCandelariaPM25[" pm25"] = laCandelariaPM25[" pm25"].astype(np.int32)

# %%
laCandelariaPM25Monthly = laCandelariaPM25.resample("ME", on="date").mean().reset_index()
laCandelariaPM25Yearly = laCandelariaPM25.resample("YE", on="date").mean().reset_index()

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(laCandelariaPM25['date'], laCandelariaPM25[' pm25'])
ax[0].set_title('Daily PM25')
ax[1].plot(laCandelariaPM25Monthly['date'], laCandelariaPM25Monthly[' pm25'])
ax[1].set_title('Monthly PM25')
ax[2].plot(laCandelariaPM25Yearly['date'], laCandelariaPM25Yearly[' pm25'])
ax[2].set_title('Yearly PM25')
plt.tight_layout()

# %% [markdown]
# #### Belen

# %%
belenPM25 = pd.read_csv("../../../Data/belén,-medellín-air-quality.csv")

# %%
belenPM25["date"] = pd.to_datetime(belenPM25["date"])
belenPM25.sort_values(by="date", inplace=True)
belenPM25Monthly = belenPM25.resample("ME", on="date").mean().reset_index()
belenPM25Yearly = villaHermosaPM25.resample("YE", on="date").mean().reset_index()

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(belenPM25['date'], belenPM25[' pm25'])
ax[0].set_title('Daily PM25')
ax[1].plot(belenPM25Monthly['date'], belenPM25Monthly[' pm25'])
ax[1].set_title('Monthly PM25')
ax[2].plot(belenPM25Yearly['date'], belenPM25Yearly[' pm25'])
ax[2].set_title('Yearly PM25')
plt.tight_layout()

# %%
# Merge all the dataframes on the "date" column
all_places_df = AranjuezPM25[['date', ' pm25']].rename(columns={' pm25': 'AranjuezPM25'}).merge(
    PobladoPM25[['date', ' pm25']].rename(columns={' pm25': 'PobladoPM25'}),
    on='date', how='outer').merge(
    sanCristobalPM25[['date', ' pm25']].rename(columns={' pm25': 'sanCristobalPM25'}),
    on='date', how='outer').merge(
    villaHermosaPM25[['date', ' pm25']].rename(columns={' pm25': 'villaHermosaPM25'}),
    on='date', how='outer').merge(
    laCandelariaPM25[['date', ' pm25']].rename(columns={' pm25': 'laCandelariaPM25'}),
    on='date', how='outer').merge(
    belenPM25[['date', ' pm25']].rename(columns={' pm25': 'belenPM25'}),
    on='date', how='outer')
    

# Sort the dataframe by date
all_places_df.sort_values(by='date', inplace=True)

# Reset the index
all_places_df.reset_index(drop=True, inplace=True)

# %%
all_places= all_places_df[(all_places_df['date'] >= '2020-01-01')]

# %%
all_places.to_csv("../../../Data/datosPM25.csv")

# %%
all_places_df = all_places_df.resample("ME", on="date").mean().reset_index()

# %%
# Melt the dataframe to have 'place', 'date', and 'pm25' columns
melted_df = all_places_df.melt(id_vars=['date'], var_name='place', value_name='pm25')
# Drop rows with NaN values in 'pm25'
melted_df.dropna(subset=['pm25'], inplace=True)
# Reset the index
melted_df.reset_index(drop=True, inplace=True)

# %%
all_places_df
# Out:
#           date  AranjuezPM25  PobladoPM25  sanCristobalPM25  villaHermosaPM25  \
# 0   2015-06-30           NaN          NaN               NaN               NaN
# 1   2015-07-31           NaN          NaN               NaN               NaN
# 2   2015-08-31           NaN          NaN               NaN               NaN
# 3   2015-09-30           NaN          NaN               NaN               NaN
# 4   2015-10-31           NaN          NaN               NaN               NaN
# ..         ...           ...          ...               ...               ...
# 109 2024-07-31     52.645161    48.161290         47.464286         46.433333
# 110 2024-08-31     57.580645    53.741935         51.709677         52.066667
# 111 2024-09-30     65.178571    60.285714         58.964286         58.500000
# 112 2024-10-31     59.193548    52.354839         52.935484         54.000000
# 113 2024-11-30     58.727273    43.888889         40.200000         45.363636
#
#      laCandelariaPM25  belenPM25
# ...

# %%
import geopandas as gpd
geo_df = gpd.read_file("../../../Data/comunas_y_corregimientos.geojson")
geo_df = geo_df.drop([19,21],axis = 0)
geo_df = geo_df.astype({"codigo":"int64"})

# %%
geo_df.set_index("codigo",inplace=True)

# %%
melted_df['place'] = melted_df['place'].str.replace('PM25', '').str.replace('([a-z])([A-Z])', r'\1 \2')

# %%
melted_df.place.unique()
# Out:
# array(['Aranjuez', 'Poblado', 'sanCristobal', 'villaHermosa',
#        'laCandelaria', 'belen'], dtype=object)

# %%
codigosDict = {
    "Aranjuez":4,
    "Poblado": 14,
    "Villa Hermosa":9,
    "laCandelaria":10,
    "belen":16
}

# %%
melted_df["codigo"] = melted_df["place"].map(codigosDict)

# %%
total = geo_df.merge(melted_df,on = "codigo")

# %%
total.to_file("../../../un/pm25.json",driver = "GeoJSON")

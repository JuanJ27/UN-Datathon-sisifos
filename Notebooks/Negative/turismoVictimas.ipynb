# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/linux/Escritorio/Darwin /Datathon/Turistas_v_ctimas_de_delitos_en_Colombia_20241110.csv')
df.head()
# Out:
#                      FECHA      PAÍS    DEPARTAMENTO         MUNICIPIO  \
# 0  2022-01-01T00:00:00.000  COLOMBIA  M. SANTA MARTA  Santa Marta (CT)
# 1  2022-01-01T00:00:00.000  COLOMBIA  M. SANTA MARTA  Santa Marta (CT)
# 2  2022-01-01T00:00:00.000  COLOMBIA  M. SANTA MARTA  Santa Marta (CT)
# 3  2022-01-02T00:00:00.000  COLOMBIA     M. MEDELLÍN     Medellín (CT)
# 4  2022-01-03T00:00:00.000  COLOMBIA  M. SANTA MARTA  Santa Marta (CT)
#
#                          DELITO PAIS VÍCTIMA     GENERO    ZONA  \
# 0  ARTÍCULO 239. HURTO PERSONAS     COLOMBIA   FEMENINO  URBANA
# 1  ARTÍCULO 239. HURTO PERSONAS     COLOMBIA  MASCULINO  URBANA
# 2  ARTÍCULO 239. HURTO PERSONAS     COLOMBIA  MASCULINO  URBANA
# 3  ARTÍCULO 239. HURTO PERSONAS        CHINA  MASCULINO  URBANA
# 4  ARTÍCULO 239. HURTO PERSONAS     COLOMBIA  MASCULINO  URBANA
#
#   CIRCUNSTANCIASPERSONA
# 0              COLOMBIA
# 1              COLOMBIA
# 2              COLOMBIA
# 3                 CHINA
# 4              COLOMBIA

# %%
df[df['DEPARTAMENTO'] == 'M. MEDELLÍN'].head()
# Out:
#                       FECHA      PAÍS DEPARTAMENTO      MUNICIPIO  \
# 3   2022-01-02T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 6   2022-01-05T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 34  2022-01-21T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 35  2022-01-21T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 36  2022-01-21T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
#
#                                 DELITO               PAIS VÍCTIMA     GENERO  \
# 3         ARTÍCULO 239. HURTO PERSONAS                      CHINA  MASCULINO
# 6         ARTÍCULO 239. HURTO PERSONAS  ESTADOS UNIDOS DE AMERICA  MASCULINO
# 34  ARTÍCULO 206. ACTO SEXUAL VIOLENTO                      CHILE   FEMENINO
# 35        ARTÍCULO 239. HURTO PERSONAS                     MEXICO  MASCULINO
# 36     ARTÍCULO 239. HURTO RESIDENCIAS                          -  MASCULINO
#
#       ZONA      CIRCUNSTANCIASPERSONA
# 3   URBANA                      CHINA
# ...

# %%
df['MUNICIPIO'].unique()
# Out:
# array(['Santa Marta (CT)', 'Medellín (CT)', 'Santiago de Tolú', 'Coveñas',
#        'Uribia', 'Villavicencio (CT)', 'Ciénaga', 'Lérida',
#        'Cartagena (CT)', 'Garzón', 'Ovejas', 'San Agustín',
#        'Leticia (CT)', 'Cali (CT)', 'Malambo', 'Manaure', 'Gigante',
#        'Santa Rosa de Osos', 'Sitionuevo', 'Tibú',
#        'San José del Guaviare (CT)', 'Manizales (CT)', 'Planeta Rica',
#        'Dibulla', 'Rionegro', 'Puebloviejo', 'Riohacha (CT)',
#        'Sincelejo (CT)', 'Itagui', 'Puerto Nariño', 'Salento',
#        'Popayán (CT)', 'Bogotá D.C. (CT)', 'Pasto (CT)', 'San Marcos',
#        'Envigado', 'Guatapé', 'Santa Rosa de Cabal', 'Pitalito',
#        'Barranquilla (CT)', 'Sabaneta', 'Bello'], dtype=object)

# %%
df[df['MUNICIPIO'] == 'Medellín (CT)']
# Out:
#                        FECHA      PAÍS DEPARTAMENTO      MUNICIPIO  \
# 3    2022-01-02T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 6    2022-01-05T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 34   2022-01-21T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 35   2022-01-21T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# 36   2022-01-21T00:00:00.000  COLOMBIA  M. MEDELLÍN  Medellín (CT)
# ..                       ...       ...          ...            ...
# 666  2024-03-06T00:00:00.000  COLOMBIA    ANTIOQUIA  Medellín (CT)
# 667  2024-01-20T00:00:00.000  COLOMBIA    ANTIOQUIA  Medellín (CT)
# 668  2024-02-03T00:00:00.000  COLOMBIA    ANTIOQUIA  Medellín (CT)
# 669  2024-08-11T00:00:00.000  COLOMBIA    ANTIOQUIA  Medellín (CT)
# 670  2024-01-24T00:00:00.000  COLOMBIA    ANTIOQUIA  Medellín (CT)
#
#                                                 DELITO  \
# 3                         ARTÍCULO 239. HURTO PERSONAS
# ...

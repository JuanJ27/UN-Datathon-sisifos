# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/linux/Escritorio/Darwin /Datathon/vbg/embarazo_adolescente.csv')
df
# Out:
#             ID  CODPTORE  CODMUNRE               fecha_nacimiento   ANO  MES  \
# 0            1         5         1  2012-11-03T00:00:00.000-05:00  2012   11
# 1            2         5         1  2012-04-08T00:00:00.000-05:00  2012    4
# 2            3         5         1  2012-03-31T00:00:00.000-05:00  2012    3
# 3            4         5         1  2012-04-25T00:00:00.000-05:00  2012    4
# 4            5         5         1  2012-06-15T00:00:00.000-05:00  2012    6
# ...        ...       ...       ...                            ...   ...  ...
# 301583  332600         5         1  2021-01-26T00:00:00.000-05:00  2021    1
# 301584  332601         5         1  2021-01-26T00:00:00.000-05:00  2021    1
# 301585  332602         5         1  2021-01-26T00:00:00.000-05:00  2021    1
# 301586  332603         5         1  2021-01-26T00:00:00.000-05:00  2021    1
# 301587  332604         5         1  2021-01-26T00:00:00.000-05:00  2021    1
#
# ...
